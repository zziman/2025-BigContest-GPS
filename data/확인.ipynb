# %%
import pandas as pd

df = pd.read_csv('franchise_data_addmetrics.csv')
df_biz = pd.read_csv('biz_area_addmetrics.csv')

# %%
len(df.columns)
# Out:
# 89

# %%
df["가맹점_구분번호"].iloc[0]
# Out:
# '761947ABD9'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72255 entries, 0 to 72254
# Data columns (total 89 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   가맹점_구분번호              72255 non-null  object
#  1   기준년월                  72255 non-null  int64
#  2   가맹점_운영개월_수_구간         72255 non-null  object
#  3   매출금액_구간               72255 non-null  object
#  4   매출건수_구간               72255 non-null  object
#  5   유니크_고객_수_구간           72255 non-null  object
#  6   객단가_구간                72255 non-null  object
#  7   취소율_구간                72255 non-null  object
#  8   배달매출금액_비율             72255 non-null  float64
#  9   동일_업종_매출금액_비율         72255 non-null  float64
#  10  동일_업종_매출건수_비율         72255 non-null  float64
#  11  동일_업종_내_매출_순위_비율      72255 non-null  float64
#  12  동일_상권_내_매출_순위_비율      72255 non-null  float64
#  13  동일_업종_내_해지_가맹점_비중     72255 non-null  float64
# ...

# %%
df[df['가맹점_구분번호']=='761947ABD9']
# Out:
#       가맹점_구분번호    기준년월 가맹점_운영개월_수_구간   매출금액_구간   매출건수_구간 유니크_고객_수_구간   객단가_구간  \
# 0   761947ABD9  202310      2_10-25%  2_10-25%  4_50-75%    4_50-75%  1_10%이하
# 1   761947ABD9  202407      2_10-25%   1_10%이하  4_50-75%    3_25-50%  1_10%이하
# 2   761947ABD9  202404      2_10-25%   1_10%이하  4_50-75%    3_25-50%  1_10%이하
# 3   761947ABD9  202307      2_10-25%   1_10%이하  3_25-50%    3_25-50%  1_10%이하
# 4   761947ABD9  202312      2_10-25%   1_10%이하  4_50-75%    3_25-50%  1_10%이하
# 5   761947ABD9  202306      2_10-25%   1_10%이하  4_50-75%    3_25-50%  1_10%이하
# 6   761947ABD9  202403      2_10-25%   1_10%이하  3_25-50%    3_25-50%  1_10%이하
# 7   761947ABD9  202308      2_10-25%   1_10%이하  3_25-50%    3_25-50%  1_10%이하
# 8   761947ABD9  202411      2_10-25%   1_10%이하  4_50-75%    4_50-75%  1_10%이하
# 9   761947ABD9  202304      2_10-25%   1_10%이하  3_25-50%    3_25-50%  1_10%이하
# 10  761947ABD9  202303      2_10-25%   1_10%이하  3_25-50%    3_25-50%  1_10%이하
# ...

# %%
lst = []
for i in df_biz.columns: 
    lst.append(i)

print(len(lst))
# Out:
# 188
